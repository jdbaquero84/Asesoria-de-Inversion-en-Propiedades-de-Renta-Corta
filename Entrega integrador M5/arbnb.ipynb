# %%
import pandas as pd
import numpy as np
import os

# %%
calendar =pd.read_csv('calendar.csv',encoding='utf-8')

# %%
listings =pd.read_csv('listings.csv',encoding='utf-8')
# Out:
# C:\Users\57319\AppData\Local\Temp\ipykernel_2692\2752411743.py:1: DtypeWarning: Columns (61,62,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   listings =pd.read_csv('listings.csv',encoding='utf-8')

# %%
reviews=pd.read_csv('reviews.csv', encoding='utf-8')

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8661286 entries, 0 to 8661285
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 462.6+ MB

# %%
print(calendar.isna().sum())
# Out:
# listing_id          0
# date                0
# available           0
# price               0
# adjusted_price      0
# minimum_nights    105
# maximum_nights    105
# dtype: int64

# %%
promedio_minights=calendar['minimum_nights'].mean()
print(promedio_minights)
# Out:
# 6.043400432342887

# %%
promedio_maxnights=calendar['maximum_nights'].mean()
print(promedio_maxnights)
# Out:
# 768.5193377208027

# %%
calendar['minimum_nights'].fillna(6, inplace=True)
# Out:
# C:\Users\57319\AppData\Local\Temp\ipykernel_2692\2688225071.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   calendar['minimum_nights'].fillna(6, inplace=True)

# %%
calendar['maximum_nights'].fillna(768, inplace=True)
# Out:
# C:\Users\57319\AppData\Local\Temp\ipykernel_2692\3420130726.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   calendar['maximum_nights'].fillna(768, inplace=True)

# %%
print(calendar.isna().sum())
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar
# Out:
#          listing_id        date available      price adjusted_price  \
# 0             50778  2020-04-26         f  $2,655.00      $2,655.00
# 1            133654  2020-04-27         t  $1,150.00      $1,150.00
# 2            133654  2020-04-28         t  $1,150.00      $1,150.00
# 3            133654  2020-04-29         t  $1,150.00      $1,150.00
# 4            133654  2020-04-30         t  $1,150.00      $1,150.00
# ...             ...         ...       ...        ...            ...
# 8661281    43178560  2021-04-21         f  $3,319.00      $3,319.00
# 8661282    43178560  2021-04-22         f  $3,319.00      $3,319.00
# 8661283    43178560  2021-04-23         f  $3,319.00      $3,319.00
# 8661284    43178560  2021-04-24         f  $3,319.00      $3,319.00
# 8661285    43178560  2021-04-25         f  $3,319.00      $3,319.00
#
#          minimum_nights  maximum_nights
# 0                   5.0          1125.0
# 1                   4.0          1125.0
# ...

# %%
calendar['minimum_nights']=calendar['minimum_nights'].astype(int)
calendar['maximum_nights']=calendar['maximum_nights'].astype(int)

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8661286 entries, 0 to 8661285
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int32
#  6   maximum_nights  int32
# dtypes: int32(2), int64(1), object(4)
# memory usage: 396.5+ MB

# %%
calendar.head(50)
# Out:
#     listing_id        date available    price adjusted_price  minimum_nights  \
# 0        50778  2020-04-26         f  2655.00      $2,655.00               5
# 1       133654  2020-04-27         t  1150.00      $1,150.00               4
# 2       133654  2020-04-28         t  1150.00      $1,150.00               4
# 3       133654  2020-04-29         t  1150.00      $1,150.00               4
# 4       133654  2020-04-30         t  1150.00      $1,150.00               4
# 5       133654  2020-05-01         t  1150.00      $1,150.00               4
# 6       133654  2020-05-02         t  1150.00      $1,150.00               4
# 7       133654  2020-05-03         t  1150.00      $1,150.00               4
# 8       133654  2020-05-04         t  1150.00      $1,150.00               4
# 9       133654  2020-05-05         t  1150.00      $1,150.00               4
# 10      133654  2020-05-06         t  1150.00      $1,150.00               4
# ...

# %%
calendar.loc[calendar['price'].str.contains('$', case=False), 'price']=calendar['price'].str.replace('$','', case=False)

# %%
calendar.loc[calendar['price'].str.contains('$', case=False), 'price']=calendar['price'].str.replace('$','', case=False)

# %%
calendar.loc[calendar['price'].str.contains(',', case=False), 'price']=calendar['price'].str.replace(',','', case=False)

# %%
#calendar.to_csv('calendario.csv', index=False)

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23729 entries, 0 to 23728
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(23), int64(21), object(62)
# memory usage: 19.2+ MB

# %%
#listings.head(3)

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
#print(listings.isna().sum())

# %%
listings.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  2.372900e+04  2.372900e+04            0.0         0.0             0.0
# mean   2.668555e+07  2.020043e+13            NaN         NaN             NaN
# std    1.263388e+07  0.000000e+00            NaN         NaN             NaN
# min    1.150800e+04  2.020043e+13            NaN         NaN             NaN
# 25%    1.765680e+07  2.020043e+13            NaN         NaN             NaN
# 50%    3.000878e+07  2.020043e+13            NaN         NaN             NaN
# 75%    3.736241e+07  2.020043e+13            NaN         NaN             NaN
# max    4.328606e+07  2.020043e+13            NaN         NaN             NaN
#
#             host_id  host_listings_count  host_total_listings_count  \
# count  2.372900e+04         23726.000000               23726.000000
# mean   1.052637e+08             9.765869                   9.765869
# std    9.990251e+07            70.044391                  70.044391
# ...

# %%
listings.shape
# Out:
# (23729, 106)

# %%
calendar.shape
# Out:
# (8661286, 7)

# %%
reviews.shape
# Out:
# (387099, 6)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387099 entries, 0 to 387098
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     387099 non-null  int64
#  1   id             387099 non-null  int64
#  2   date           387099 non-null  object
#  3   reviewer_id    387099 non-null  int64
#  4   reviewer_name  387099 non-null  object
#  5   comments       386923 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 17.7+ MB

# %%
print(reviews.isna().sum())
# Out:
# listing_id         0
# id                 0
# date               0
# reviewer_id        0
# reviewer_name      0
# comments         176
# dtype: int64

# %%
reviews['comments'].fillna('Sin comentarios', inplace=True)
# Out:
# C:\Users\57319\AppData\Local\Temp\ipykernel_2692\90144050.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   reviews['comments'].fillna('Sin comentarios', inplace=True)

# %%
print(reviews.isna().sum())
# Out:
# listing_id       0
# id               0
# date             0
# reviewer_id      0
# reviewer_name    0
# comments         0
# dtype: int64

# %%
#reviews

# %%
reviews.drop('reviewer_name', axis=1, inplace=True)

# %%
print(reviews.isna().sum())
# Out:
# listing_id     0
# id             0
# date           0
# reviewer_id    0
# comments       0
# dtype: int64

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387099 entries, 0 to 387098
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   listing_id   387099 non-null  int64
#  1   id           387099 non-null  int64
#  2   date         387099 non-null  object
#  3   reviewer_id  387099 non-null  int64
#  4   comments     387099 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 14.8+ MB

# %%
listas= listings[['id','host_id','host_acceptance_rate','city','state','country','latitude','longitude','property_type','room_type',
                  'bathrooms','bedrooms','price','review_scores_rating']].copy()

# %%
listas.shape
# Out:
# (23729, 14)

# %%
print(listas.isna().sum())
# Out:
# id                         0
# host_id                    0
# host_acceptance_rate    5199
# city                     587
# state                    183
# country                    0
# latitude                   0
# longitude                  0
# property_type              0
# room_type                  0
# bathrooms                 62
# bedrooms                  43
# price                      0
# review_scores_rating    6890
# dtype: int64

# %%
listas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23729 entries, 0 to 23728
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    23729 non-null  int64
#  1   host_id               23729 non-null  int64
#  2   city                  23729 non-null  object
#  3   state                 23729 non-null  object
#  4   country               23729 non-null  object
#  5   latitude              23729 non-null  float64
#  6   longitude             23729 non-null  float64
#  7   property_type         23729 non-null  object
#  8   room_type             23729 non-null  object
#  9   bathrooms             23729 non-null  float64
#  10  price                 23729 non-null  object
#  11  review_scores_rating  23729 non-null  float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 2.2+ MB

# %%
listas.drop('host_acceptance_rate', axis=1, inplace=True)

# %%
listas.drop('bedrooms', axis=1, inplace=True)

# %%
filtro=listas[listas['bathrooms'].isna()]
filtro

# %%
tiposPropiedad= listas['property_type'].unique()
print(tiposPropiedad)
# Out:
# ['Condominium' 'Apartment' 'Bed and breakfast' 'Other' 'Loft' 'House'
#  'Townhouse' 'Aparthotel' 'Serviced apartment' 'Guest suite' 'Camper/RV'
#  'Car' 'Hostel' 'Guesthouse' 'Villa' 'Boutique hotel' 'Tiny house' 'Hotel'
#  'Resort' 'Cabin' 'Casa particular (Cuba)' 'Farm stay' 'Chalet' 'Bungalow'
#  'Castle' 'In-law' 'Dorm' 'Boat' 'Earth house' 'Dome house' 'Cottage'
#  'Tent' 'Pension (South Korea)' 'Campsite']

# %%
#listas['bedrooms'].fillna(listas['bedrooms'].mean(), inplace=True)

# %%
print(listas.isna().sum())
# Out:
# id                      0
# host_id                 0
# city                    0
# state                   0
# country                 0
# latitude                0
# longitude               0
# property_type           0
# room_type               0
# bathrooms               0
# price                   0
# review_scores_rating    0
# dtype: int64

# %%
listas['city'].fillna('Sin registrar', inplace=True)

# %%
listas['state'].fillna('Sin registrar', inplace=True)

# %%
listas['bathrooms'].fillna(int(1), inplace=True)

# %%
listas['review_scores_rating'].fillna(listas['review_scores_rating'].mean(), inplace=True)

# %%
listas.head(20)

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
nombresCiudades= listas['city'].unique()
print(nombresCiudades)
# Out:
# [' CABA' 'Palermo/ CABA' 'Retiro' 'Palermo' 'CABA' 'Sin registrar' 'CABA '
#  'Recoleta' 'Monserrat' 'Almagro' '1425  CABA' ' CABA ' 'Capital federal'
#  'Capital Federal' 'Las Canitas,  CABA' 'Constitución' 'San Nicolas'
#  'Palermo Soho' 'Palermo Hollywood' 'Reoleta' 'San Telmo' 'CF'
#  'Colegiales, CABA' ' CABA. Palermo' 'Ciudad Autonoma de  CABA'
#  ' CABA - CAPITAL' 'Recoleta,  CABA' ' CABA / Puerto Madero'
#  ' CABA, Argentina' 'Autonomous City of  CABA' 'Palermo,  CABA' 'Centro'
#  'ciudad autonoma de  CABA' ' CABA - Caballito -' 'Las Cañitas Palermo'
#  'San Nicolás' ' CABA, Capital Federal, Palermo' 'Belgrano' 'Nuñez'
#  ' CABA Capital Federal' 'Coghlan' ' CABA / Almagro' 'La Boca' 'recoleta'
#  'Palermo SOHO' 'Balvanera' ' CABA caba ' 'Буэнос-Айрес'
#  'Cuidad Autónoma de  CABA' ' CABA - ' 'Villa Urquiza' 'CABA, Palermo'
#  'Vicente López' ' CABA,capital' ' CABA, Barrio de Colegiales' 'Congreso'
#  'Núñez' 'Microcentro' 'San Telmo,   CABA' ' CABA, Palermo'
# ...

# %%
listas['city'].fillna('Sin registrar', inplace=True)

# %%
listas[listas['city'].str.contains('Aires')]

# %%
nombresPais= listas['country'].unique()
print(nombresPais)
# Out:
# ['Argentina' 'Saint Martin']

# %%
listas.loc[listas['city'].str.contains('Aires', case=False), 'city']=listas['city'].str.replace('Aires','CABA', case=False)

# %%
listas.loc[listas['city'].str.contains('Buenos', case=False), 'city']=listas['city'].str.replace('Buenos','', case=False)

# %%
listas.loc[listas['city'].str.contains('Ciudad autónoma de  ', case=False), 'city']=listas['city'].str.replace('Ciudad autónoma de  ','', case=False)

# %%
listas.loc[listas['city'].str.contains('ciudad de  ', case=False), 'city']=listas['city'].str.replace('ciudad de  ','', case=False)

# %%
listas.loc[listas['city'].str.contains('ciudad de  ', case=False), 'city']=listas['city'].str.replace('ciudad de  ','', case=False)

# %%
print(listas['price'][3])
# Out:
# 2987.00

# %%
listas['price']=listings['price']

# %%
listas.loc[listas['price'].str.contains('$', case=False), 'price']=listas['price'].str.replace('$','', case=False)

# %%
listas.loc[listas['price'].str.contains(',', case=False), 'price']=listas['price'].str.replace(',','', case=False)

# %%
#listas['price'].str.replace('$','')

# %%
#listas['price'].str.replace(',','')

# %%
listas.head(20)
# Out:
#        id  host_id           city                            state    country  \
# 0   11508    42762           CABA                  Capital Federal  Argentina
# 1   12463    48799           CABA                  Capital Federal  Argentina
# 2   13095    50994           CABA                  Capital Federal  Argentina
# 3   13096    50994           CABA                  Capital Federal  Argentina
# 4   13097    50994           CABA                  Capital Federal  Argentina
# 5   13099    50994           CABA                  Capital Federal  Argentina
# 6   13100    50994           CABA                  Capital Federal  Argentina
# 7   14222    55825  Palermo/ CABA  Autonomous City of Buenos Aires  Argentina
# 8   14711    57770           CABA                  Capital Federal  Argentina
# 9   15074    59338           CABA  Autonomous City of Buenos Aires  Argentina
# 10  15889    62183           CABA                  Capital Federal  Argentina
# ...

# %%
#calendar.to_csv('calendario.csv', index=False)

# %%
#calendar.to_csv('calendario.csv', index=False)

# %%
listas.to_csv('listas.csv',index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
matriz_correlacion=listas.corr('review_scores_rating','bathrooms')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 matriz_correlacion=listas.corr('review_scores_rating','bathrooms')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...
